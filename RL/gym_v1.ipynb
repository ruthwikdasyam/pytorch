# %%
import gymnasium as gym
import time
import numpy as np

# %%
from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
# Create our training environment - a cart with a pole that needs balancing
env = gym.make("LunarLander-v3", continuous=False, gravity=-10.0, enable_wind=False, wind_power=15.0, turbulence_power=1.5, render_mode="human")

# Reset environment to start a new episode
observation, info = env.reset()
print(f"Starting observation: {observation}")

episode_over = False
total_reward = 0

while not episode_over:
    action = env.action_space.sample()  # Random action for now - real agents will be smarter!

    # Take the action and see what happens
    observation, reward, terminated, truncated, info = env.step(action)
 
    total_reward += reward
    # print(f"Action taken: {action}, New observation: {observation}, Reward: {reward}")
    episode_over = terminated or truncated
    time.sleep(0.2)  # Slow down the loop to see the action

print(f"Episode finished! Total reward: {total_reward}")
env.close()
# Out:
# Starting observation: [-7.3537824e-04  1.4168624e+00 -7.4500605e-02  2.6409853e-01
#   8.5887959e-04  1.6875466e-02  0.0000000e+00  0.0000000e+00]
# Episode finished! Total reward: -129.28694039649886

# %%
# Create the environment
env = make_vec_env('LunarLander-v3', n_envs=5)

model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cpu device

# %%
# SOLUTION
# Train it for 1,000,000 timesteps
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v1"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.9     |
# |    ep_rew_mean     | -155     |
# | time/              |          |
# |    fps             | 6000     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 5120     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96           |
# |    ep_rew_mean          | -169         |
# | time/                   |              |
# |    fps                  | 4865         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0012887996 |
# |    clip_fraction        | 0.000342     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00093      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.61e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 4.4e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.1         |
# |    ep_rew_mean          | -175         |
# | time/                   |              |
# |    fps                  | 4651         |
# |    iterations           | 3            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 15360        |
# | train/                  |              |
# |    approx_kl            | 0.0043653576 |
# |    clip_fraction        | 0.00957      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00237     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.07e+03     |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.00491     |
# |    value_loss           | 5.29e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.1         |
# |    ep_rew_mean          | -147         |
# | time/                   |              |
# |    fps                  | 4572         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0068427385 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.00577     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.87e+03     |
# |    n_updates            | 12           |
# |    policy_gradient_loss | -0.00611     |
# |    value_loss           | 4.1e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 99.4        |
# |    ep_rew_mean          | -125        |
# | time/                   |             |
# |    fps                  | 4494        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.008899558 |
# |    clip_fraction        | 0.0371      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.0159     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 639         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00424    |
# |    value_loss           | 1.77e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -130        |
# | time/                   |             |
# |    fps                  | 4385        |
# |    iterations           | 6           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007821801 |
# |    clip_fraction        | 0.033       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.00164    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 631         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00504    |
# |    value_loss           | 1.81e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 98.9         |
# |    ep_rew_mean          | -127         |
# | time/                   |              |
# |    fps                  | 4313         |
# |    iterations           | 7            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0057860585 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | -0.0416      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+03     |
# |    n_updates            | 24           |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 1.8e+03      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99.6       |
# |    ep_rew_mean          | -124       |
# | time/                   |            |
# |    fps                  | 4271       |
# |    iterations           | 8          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00806625 |
# |    clip_fraction        | 0.026      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.35      |
# |    explained_variance   | -0.0059    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 536        |
# |    n_updates            | 28         |
# |    policy_gradient_loss | -0.00422   |
# |    value_loss           | 1.24e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 104        |
# |    ep_rew_mean          | -112       |
# | time/                   |            |
# |    fps                  | 4217       |
# |    iterations           | 9          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 46080      |
# | train/                  |            |
# |    approx_kl            | 0.00975596 |
# |    clip_fraction        | 0.0931     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | -0.00196   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 494        |
# |    n_updates            | 32         |
# |    policy_gradient_loss | -0.00891   |
# |    value_loss           | 1.4e+03    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 4194        |
# |    iterations           | 10          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008520784 |
# |    clip_fraction        | 0.0673      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.000241   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 328         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00224    |
# |    value_loss           | 1.06e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 108         |
# |    ep_rew_mean          | -103        |
# | time/                   |             |
# |    fps                  | 4132        |
# |    iterations           | 11          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 56320       |
# | train/                  |             |
# |    approx_kl            | 0.001994598 |
# |    clip_fraction        | 0.00181     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.000249   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 265         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 1.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 118         |
# |    ep_rew_mean          | -89.7       |
# | time/                   |             |
# |    fps                  | 3828        |
# |    iterations           | 12          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011963164 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0057      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 279         |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.00786    |
# |    value_loss           | 586         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 134         |
# |    ep_rew_mean          | -85.6       |
# | time/                   |             |
# |    fps                  | 3765        |
# |    iterations           | 13          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 66560       |
# | train/                  |             |
# |    approx_kl            | 0.008487184 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.0389     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 252         |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00505    |
# |    value_loss           | 760         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | -89          |
# | time/                   |              |
# |    fps                  | 3720         |
# |    iterations           | 14           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0052498034 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | -0.0217      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 214          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 624          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 160         |
# |    ep_rew_mean          | -79.9       |
# | time/                   |             |
# |    fps                  | 3603        |
# |    iterations           | 15          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 76800       |
# | train/                  |             |
# |    approx_kl            | 0.005735028 |
# |    clip_fraction        | 0.0269      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -0.0756     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 242         |
# |    n_updates            | 56          |
# |    policy_gradient_loss | -0.0052     |
# |    value_loss           | 633         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 155         |
# |    ep_rew_mean          | -66.4       |
# | time/                   |             |
# |    fps                  | 3578        |
# |    iterations           | 16          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006190942 |
# |    clip_fraction        | 0.051       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0765      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 426         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0054     |
# |    value_loss           | 610         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 152         |
# |    ep_rew_mean          | -39.4       |
# | time/                   |             |
# |    fps                  | 3428        |
# |    iterations           | 17          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 87040       |
# | train/                  |             |
# |    approx_kl            | 0.005278504 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.0552      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 190         |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.00412    |
# |    value_loss           | 440         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 161         |
# |    ep_rew_mean          | -37.4       |
# | time/                   |             |
# |    fps                  | 3110        |
# |    iterations           | 18          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.007442986 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.138       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 191         |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.00539    |
# |    value_loss           | 510         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 165          |
# |    ep_rew_mean          | -33          |
# | time/                   |              |
# |    fps                  | 2863         |
# |    iterations           | 19           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 97280        |
# | train/                  |              |
# |    approx_kl            | 0.0060232407 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.424        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 216          |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00556     |
# |    value_loss           | 274          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 195          |
# |    ep_rew_mean          | -34.9        |
# | time/                   |              |
# |    fps                  | 2477         |
# |    iterations           | 20           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0037350778 |
# |    clip_fraction        | 0.00718      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.382        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 115          |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 482          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 232          |
# |    ep_rew_mean          | -37.3        |
# | time/                   |              |
# |    fps                  | 2367         |
# |    iterations           | 21           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 107520       |
# | train/                  |              |
# |    approx_kl            | 0.0039437534 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.599        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 115          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 238          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 267          |
# |    ep_rew_mean          | -34.3        |
# | time/                   |              |
# |    fps                  | 2194         |
# |    iterations           | 22           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0040958007 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.448        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 236          |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 571          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 296         |
# |    ep_rew_mean          | -26.7       |
# | time/                   |             |
# |    fps                  | 2092        |
# |    iterations           | 23          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 117760      |
# | train/                  |             |
# |    approx_kl            | 0.005320127 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.779       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 90.3        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 202         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 304          |
# |    ep_rew_mean          | -22.8        |
# | time/                   |              |
# |    fps                  | 2036         |
# |    iterations           | 24           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0061859684 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51           |
# |    n_updates            | 92           |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 205          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | -21.1       |
# | time/                   |             |
# |    fps                  | 1978        |
# |    iterations           | 25          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 128000      |
# | train/                  |             |
# |    approx_kl            | 0.006600301 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.00568    |
# |    value_loss           | 198         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 366         |
# |    ep_rew_mean          | -16.3       |
# | time/                   |             |
# |    fps                  | 1900        |
# |    iterations           | 26          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 133120      |
# | train/                  |             |
# |    approx_kl            | 0.005936694 |
# |    clip_fraction        | 0.0367      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.5        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00252    |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 377         |
# |    ep_rew_mean          | -11.5       |
# | time/                   |             |
# |    fps                  | 1883        |
# |    iterations           | 27          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 138240      |
# | train/                  |             |
# |    approx_kl            | 0.005742755 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.9        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00368    |
# |    value_loss           | 130         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 368          |
# |    ep_rew_mean          | -15.2        |
# | time/                   |              |
# |    fps                  | 1859         |
# |    iterations           | 28           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0033560127 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 92.5         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.00231     |
# |    value_loss           | 154          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 401          |
# |    ep_rew_mean          | -9.65        |
# | time/                   |              |
# |    fps                  | 1820         |
# |    iterations           | 29           |
# |    time_elapsed         | 81           |
# |    total_timesteps      | 148480       |
# | train/                  |              |
# |    approx_kl            | 0.0024992924 |
# |    clip_fraction        | 0.00132      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.553        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 185          |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 503          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 417         |
# |    ep_rew_mean          | -10         |
# | time/                   |             |
# |    fps                  | 1791        |
# |    iterations           | 30          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 153600      |
# | train/                  |             |
# |    approx_kl            | 0.002748296 |
# |    clip_fraction        | 0.0082      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.5        |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 445         |
# |    ep_rew_mean          | -7.5        |
# | time/                   |             |
# |    fps                  | 1783        |
# |    iterations           | 31          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 158720      |
# | train/                  |             |
# |    approx_kl            | 0.006150171 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 93.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 450         |
# |    ep_rew_mean          | -6.01       |
# | time/                   |             |
# |    fps                  | 1773        |
# |    iterations           | 32          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.007700816 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 115         |
# |    n_updates            | 124         |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 264         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 471          |
# |    ep_rew_mean          | -3.08        |
# | time/                   |              |
# |    fps                  | 1729         |
# |    iterations           | 33           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 168960       |
# | train/                  |              |
# |    approx_kl            | 0.0035101227 |
# |    clip_fraction        | 0.00557      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.599        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 136          |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.000966    |
# |    value_loss           | 345          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 508          |
# |    ep_rew_mean          | 2.92         |
# | time/                   |              |
# |    fps                  | 1694         |
# |    iterations           | 34           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0030901153 |
# |    clip_fraction        | 0.00933      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.821        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.8         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.000952    |
# |    value_loss           | 146          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 492          |
# |    ep_rew_mean          | -2.4         |
# | time/                   |              |
# |    fps                  | 1657         |
# |    iterations           | 35           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 179200       |
# | train/                  |              |
# |    approx_kl            | 0.0034976962 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.15        |
# |    explained_variance   | 0.79         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 185          |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 222          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 495         |
# |    ep_rew_mean          | -0.73       |
# | time/                   |             |
# |    fps                  | 1641        |
# |    iterations           | 36          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.006646885 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.625       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 230         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 326         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 533          |
# |    ep_rew_mean          | 6.44         |
# | time/                   |              |
# |    fps                  | 1618         |
# |    iterations           | 37           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 189440       |
# | train/                  |              |
# |    approx_kl            | 0.0061685564 |
# |    clip_fraction        | 0.0452       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.879        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.3         |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.00267     |
# |    value_loss           | 115          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 538         |
# |    ep_rew_mean          | 10.7        |
# | time/                   |             |
# |    fps                  | 1610        |
# |    iterations           | 38          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.008147543 |
# |    clip_fraction        | 0.0963      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.00465    |
# |    value_loss           | 63.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 578          |
# |    ep_rew_mean          | 20.7         |
# | time/                   |              |
# |    fps                  | 1596         |
# |    iterations           | 39           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 199680       |
# | train/                  |              |
# |    approx_kl            | 0.0021291256 |
# |    clip_fraction        | 0.00747      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 264          |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.000593    |
# |    value_loss           | 299          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 594         |
# |    ep_rew_mean          | 25.5        |
# | time/                   |             |
# |    fps                  | 1580        |
# |    iterations           | 40          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.004985065 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.913       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26          |
# |    n_updates            | 156         |
# |    policy_gradient_loss | -0.003      |
# |    value_loss           | 64.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 618          |
# |    ep_rew_mean          | 31.3         |
# | time/                   |              |
# |    fps                  | 1561         |
# |    iterations           | 41           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 209920       |
# | train/                  |              |
# |    approx_kl            | 0.0055672177 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.786        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.1         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 198          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 636          |
# |    ep_rew_mean          | 34.9         |
# | time/                   |              |
# |    fps                  | 1548         |
# |    iterations           | 42           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 215040       |
# | train/                  |              |
# |    approx_kl            | 0.0038412516 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.7         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 40.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 635         |
# |    ep_rew_mean          | 33.8        |
# | time/                   |             |
# |    fps                  | 1515        |
# |    iterations           | 43          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 220160      |
# | train/                  |             |
# |    approx_kl            | 0.009487358 |
# |    clip_fraction        | 0.073       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.1        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.00342    |
# |    value_loss           | 56.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 667          |
# |    ep_rew_mean          | 42.3         |
# | time/                   |              |
# |    fps                  | 1497         |
# |    iterations           | 44           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 225280       |
# | train/                  |              |
# |    approx_kl            | 0.0057839407 |
# |    clip_fraction        | 0.0905       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.948        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.81         |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 27           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 684         |
# |    ep_rew_mean          | 48          |
# | time/                   |             |
# |    fps                  | 1481        |
# |    iterations           | 45          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 230400      |
# | train/                  |             |
# |    approx_kl            | 0.009502621 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.49        |
# |    n_updates            | 176         |
# |    policy_gradient_loss | -0.00213    |
# |    value_loss           | 19.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 692         |
# |    ep_rew_mean          | 48.8        |
# | time/                   |             |
# |    fps                  | 1480        |
# |    iterations           | 46          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 235520      |
# | train/                  |             |
# |    approx_kl            | 0.001862163 |
# |    clip_fraction        | 0.00977     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.2        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00116    |
# |    value_loss           | 61          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 721          |
# |    ep_rew_mean          | 57           |
# | time/                   |              |
# |    fps                  | 1467         |
# |    iterations           | 47           |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 240640       |
# | train/                  |              |
# |    approx_kl            | 0.0033795245 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.891        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.5         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 127          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 745        |
# |    ep_rew_mean          | 61.7       |
# | time/                   |            |
# |    fps                  | 1468       |
# |    iterations           | 48         |
# |    time_elapsed         | 167        |
# |    total_timesteps      | 245760     |
# | train/                  |            |
# |    approx_kl            | 0.00467792 |
# |    clip_fraction        | 0.0136     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.2       |
# |    n_updates            | 188        |
# |    policy_gradient_loss | -0.00135   |
# |    value_loss           | 31.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 754          |
# |    ep_rew_mean          | 66.2         |
# | time/                   |              |
# |    fps                  | 1471         |
# |    iterations           | 49           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 250880       |
# | train/                  |              |
# |    approx_kl            | 0.0064391866 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.973        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.49         |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00265     |
# |    value_loss           | 24.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 785          |
# |    ep_rew_mean          | 75.1         |
# | time/                   |              |
# |    fps                  | 1466         |
# |    iterations           | 50           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 256000       |
# | train/                  |              |
# |    approx_kl            | 0.0035696875 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.976       |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 86.9         |
# |    n_updates            | 196          |
# |    policy_gradient_loss | -0.000543    |
# |    value_loss           | 90.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 805          |
# |    ep_rew_mean          | 80.8         |
# | time/                   |              |
# |    fps                  | 1465         |
# |    iterations           | 51           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 261120       |
# | train/                  |              |
# |    approx_kl            | 0.0019010166 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.975       |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 73.8         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 92.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 821          |
# |    ep_rew_mean          | 84.5         |
# | time/                   |              |
# |    fps                  | 1451         |
# |    iterations           | 52           |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 266240       |
# | train/                  |              |
# |    approx_kl            | 0.0039978134 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.965       |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.86         |
# |    n_updates            | 204          |
# |    policy_gradient_loss | -0.000607    |
# |    value_loss           | 47.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 813          |
# |    ep_rew_mean          | 84.1         |
# | time/                   |              |
# |    fps                  | 1442         |
# |    iterations           | 53           |
# |    time_elapsed         | 188          |
# |    total_timesteps      | 271360       |
# | train/                  |              |
# |    approx_kl            | 0.0008865022 |
# |    clip_fraction        | 0.000586     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.975       |
# |    explained_variance   | 0.912        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.9         |
# |    n_updates            | 208          |
# |    policy_gradient_loss | 0.000194     |
# |    value_loss           | 76.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 812          |
# |    ep_rew_mean          | 83.4         |
# | time/                   |              |
# |    fps                  | 1431         |
# |    iterations           | 54           |
# |    time_elapsed         | 193          |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0051062563 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.919       |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.74         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 42.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 813          |
# |    ep_rew_mean          | 85.5         |
# | time/                   |              |
# |    fps                  | 1418         |
# |    iterations           | 55           |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 281600       |
# ...
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 1318         |
# |    iterations           | 179          |
# |    time_elapsed         | 695          |
# |    total_timesteps      | 916480       |
# | train/                  |              |
# |    approx_kl            | 0.0053440137 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.661       |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.78         |
# |    n_updates            | 712          |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 24.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 499         |
# |    ep_rew_mean          | 242         |
# | time/                   |             |
# |    fps                  | 1321        |
# |    iterations           | 180         |
# |    time_elapsed         | 697         |
# |    total_timesteps      | 921600      |
# | train/                  |             |
# |    approx_kl            | 0.003118235 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.62       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.7        |
# |    n_updates            | 716         |
# |    policy_gradient_loss | -0.00102    |
# |    value_loss           | 51.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 434          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 1325         |
# |    iterations           | 181          |
# |    time_elapsed         | 699          |
# |    total_timesteps      | 926720       |
# | train/                  |              |
# |    approx_kl            | 0.0019788097 |
# |    clip_fraction        | 0.00444      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.672       |
# |    explained_variance   | 0.793        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 77.6         |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.000608    |
# |    value_loss           | 526          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 371          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 1328         |
# |    iterations           | 182          |
# |    time_elapsed         | 701          |
# |    total_timesteps      | 931840       |
# | train/                  |              |
# |    approx_kl            | 0.0039480417 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 116          |
# |    n_updates            | 724          |
# |    policy_gradient_loss | -0.000917    |
# |    value_loss           | 199          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 343          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 1330         |
# |    iterations           | 183          |
# |    time_elapsed         | 704          |
# |    total_timesteps      | 936960       |
# | train/                  |              |
# |    approx_kl            | 0.0049879276 |
# |    clip_fraction        | 0.0276       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.756       |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 728          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 265          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 322         |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 1331        |
# |    iterations           | 184         |
# |    time_elapsed         | 707         |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.002181625 |
# |    clip_fraction        | 0.00488     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 137         |
# |    n_updates            | 732         |
# |    policy_gradient_loss | -0.000556   |
# |    value_loss           | 432         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 300          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 1332         |
# |    iterations           | 185          |
# |    time_elapsed         | 710          |
# |    total_timesteps      | 947200       |
# | train/                  |              |
# |    approx_kl            | 0.0054690703 |
# |    clip_fraction        | 0.0405       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.11         |
# |    n_updates            | 736          |
# |    policy_gradient_loss | -0.000452    |
# |    value_loss           | 21.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 306          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 1333         |
# |    iterations           | 186          |
# |    time_elapsed         | 714          |
# |    total_timesteps      | 952320       |
# | train/                  |              |
# |    approx_kl            | 0.0066929893 |
# |    clip_fraction        | 0.0494       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.696       |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.86         |
# |    n_updates            | 740          |
# |    policy_gradient_loss | 0.00111      |
# |    value_loss           | 18.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 304          |
# |    ep_rew_mean          | 260          |
# | time/                   |              |
# |    fps                  | 1334         |
# |    iterations           | 187          |
# |    time_elapsed         | 717          |
# |    total_timesteps      | 957440       |
# | train/                  |              |
# |    approx_kl            | 0.0029165752 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.71        |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.89         |
# |    n_updates            | 744          |
# |    policy_gradient_loss | -0.000313    |
# |    value_loss           | 9.57         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 300         |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 1335        |
# |    iterations           | 188         |
# |    time_elapsed         | 720         |
# |    total_timesteps      | 962560      |
# | train/                  |             |
# |    approx_kl            | 0.003419791 |
# |    clip_fraction        | 0.0331      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.708      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.24        |
# |    n_updates            | 748         |
# |    policy_gradient_loss | -9.54e-05   |
# |    value_loss           | 11          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 298          |
# |    ep_rew_mean          | 259          |
# | time/                   |              |
# |    fps                  | 1336         |
# |    iterations           | 189          |
# |    time_elapsed         | 723          |
# |    total_timesteps      | 967680       |
# | train/                  |              |
# |    approx_kl            | 0.0013316924 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.718       |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.5         |
# |    n_updates            | 752          |
# |    policy_gradient_loss | -0.000123    |
# |    value_loss           | 270          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 301          |
# |    ep_rew_mean          | 258          |
# | time/                   |              |
# |    fps                  | 1337         |
# |    iterations           | 190          |
# |    time_elapsed         | 727          |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0022778134 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | 0.822        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 146          |
# |    n_updates            | 756          |
# |    policy_gradient_loss | -0.000262    |
# |    value_loss           | 441          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | 256         |
# | time/                   |             |
# |    fps                  | 1338        |
# |    iterations           | 191         |
# |    time_elapsed         | 730         |
# |    total_timesteps      | 977920      |
# | train/                  |             |
# |    approx_kl            | 0.002204239 |
# |    clip_fraction        | 0.0259      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.03        |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.00068    |
# |    value_loss           | 20.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 303          |
# |    ep_rew_mean          | 260          |
# | time/                   |              |
# |    fps                  | 1339         |
# |    iterations           | 192          |
# |    time_elapsed         | 734          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0031184175 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.644       |
# |    explained_variance   | 0.903        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.2         |
# |    n_updates            | 764          |
# |    policy_gradient_loss | -0.000814    |
# |    value_loss           | 219          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 302         |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 1340        |
# |    iterations           | 193         |
# |    time_elapsed         | 737         |
# |    total_timesteps      | 988160      |
# | train/                  |             |
# |    approx_kl            | 0.004835372 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.726      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.53        |
# |    n_updates            | 768         |
# |    policy_gradient_loss | -0.000442   |
# |    value_loss           | 16          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 306         |
# |    ep_rew_mean          | 258         |
# | time/                   |             |
# |    fps                  | 1341        |
# |    iterations           | 194         |
# |    time_elapsed         | 740         |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.004183019 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 124         |
# |    n_updates            | 772         |
# |    policy_gradient_loss | -0.00071    |
# |    value_loss           | 371         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 305          |
# |    ep_rew_mean          | 261          |
# | time/                   |              |
# |    fps                  | 1342         |
# |    iterations           | 195          |
# |    time_elapsed         | 743          |
# |    total_timesteps      | 998400       |
# | train/                  |              |
# |    approx_kl            | 0.0054379716 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.696       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.8          |
# |    n_updates            | 776          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 11.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 296          |
# |    ep_rew_mean          | 261          |
# | time/                   |              |
# |    fps                  | 1343         |
# |    iterations           | 196          |
# |    time_elapsed         | 746          |
# |    total_timesteps      | 1003520      |
# | train/                  |              |
# |    approx_kl            | 0.0025025816 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 192          |
# |    n_updates            | 780          |
# |    policy_gradient_loss | 0.000504     |
# |    value_loss           | 247          |
# ------------------------------------------

# %%
model_path = "ppo-LunarLander-v1.zip"
# Load the model
model = PPO.load(model_path)

# %%
eval_env = Monitor(gym.make("LunarLander-v3", render_mode='human'))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=2, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=243.88 +/- 18.258336999999997

# %%
eval_env.close()

# %%
# from huggingface_hub import notebook_login
# notebook_login()  # paste your HF token with 'write' permission

# %%
model

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from huggingface_sb3 import package_to_hub
from stable_baselines3.common.monitor import Monitor

env_id = "LunarLander-v3"

# Create the evaluation env and set the render_mode="human"
eval_env = DummyVecEnv([lambda: Monitor(gym.make(env_id, render_mode="rgb_array"))])

package_to_hub(
    model=model,
    model_name="PPO-LunarLander-v3",
    model_architecture="PPO",
    env_id=env_id,
    eval_env=eval_env,
    repo_id="eequalsmcsquared/ppo-LunarLander-v3",
    commit_message="First upload from local VS Code",
)
# Out:
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# Saving video to /tmp/tmprpu0kml9/-step-0-to-step-1000.mp4
# MoviePy - Building video /tmp/tmprpu0kml9/-step-0-to-step-1000.mp4.
# MoviePy - Writing video /tmp/tmprpu0kml9/-step-0-to-step-1000.mp4
# sh: 1: ffmpeg: not found
# MoviePy - Done !
# MoviePy - video ready /tmp/tmprpu0kml9/-step-0-to-step-1000.mp4
# ℹ Pushing repo eequalsmcsquared/ppo-LunarLander-v3 to the Hugging Face
# Hub
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/eequalsmcsquared/ppo-LunarLander-v3/tree/main/
# CommitInfo(commit_url='https://huggingface.co/eequalsmcsquared/ppo-LunarLander-v3/commit/e6857d26e90e45388a8063f1729e1b76857e5a66', commit_message='First upload from local VS Code', commit_description='', oid='e6857d26e90e45388a8063f1729e1b76857e5a66', pr_url=None, repo_url=RepoUrl('https://huggingface.co/eequalsmcsquared/ppo-LunarLander-v3', endpoint='https://huggingface.co', repo_type='model', repo_id='eequalsmcsquared/ppo-LunarLander-v3'), pr_revision=None, pr_num=None)

# %%
import numpy as np
arr = np.random.randint(0,10,(3, 4))
print(arr[2])
np.argmax(arr[2])
# Out:
# [9 1 2 5]
# np.int64(0)
